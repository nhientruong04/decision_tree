# %%
from modules.tree import RegressionTree
from modules.helper import visualize_tree
from sklearn import datasets

df = datasets.load_diabetes(as_frame=True, scaled=False)['frame']
df_train = df[:350]
df_val = df[350:]

# %%
regression_tree = RegressionTree(df_train)
regression_tree.build_tree()

regression_tree.validate(df_val)
# Out:
# 55.99239130434783

# %%
visualize_tree(regression_tree.root_node)
